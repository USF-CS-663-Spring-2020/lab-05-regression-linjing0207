# %% [markdown]
# # Credit Dataset

# %%
# Target: Limit
# Predictors: Income, Rating, Cards, Age, Education

# %%
import pandas as pd

df = pd.read_csv('Credit.csv')
df
# Out:
#      Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0             1   14.891   3606     283      2   34         11    Male
# 1             2  106.025   6645     483      3   82         15  Female
# 2             3  104.593   7075     514      4   71         11    Male
# 3             4  148.924   9504     681      3   36         11  Female
# 4             5   55.882   4897     357      2   68         16    Male
# ..          ...      ...    ...     ...    ...  ...        ...     ...
# 395         396   12.096   4100     307      3   32         13    Male
# 396         397   13.364   3838     296      5   65         17    Male
# 397         398   57.872   4171     321      5   67         12  Female
# 398         399   37.728   2525     192      1   44         13    Male
# 399         400   18.701   5524     415      5   64          7  Female
#
#     Student Married         Ethnicity  Balance
# 0        No     Yes         Caucasian      333
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 12 columns):
# Unnamed: 0    400 non-null int64
# Income        400 non-null float64
# Limit         400 non-null int64
# Rating        400 non-null int64
# Cards         400 non-null int64
# Age           400 non-null int64
# Education     400 non-null int64
# Gender        400 non-null object
# Student       400 non-null object
# Married       400 non-null object
# Ethnicity     400 non-null object
# Balance       400 non-null int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 37.6+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0      Income         Limit      Rating       Cards  \
# count  400.000000  400.000000    400.000000  400.000000  400.000000
# mean   200.500000   45.218885   4735.600000  354.940000    2.957500
# std    115.614301   35.244273   2308.198848  154.724143    1.371275
# min      1.000000   10.354000    855.000000   93.000000    1.000000
# 25%    100.750000   21.007250   3088.000000  247.250000    2.000000
# 50%    200.500000   33.115500   4622.500000  344.000000    3.000000
# 75%    300.250000   57.470750   5872.750000  437.250000    4.000000
# max    400.000000  186.634000  13913.000000  982.000000    9.000000
#
#               Age   Education      Balance
# count  400.000000  400.000000   400.000000
# mean    55.667500   13.450000   520.015000
# std     17.249807    3.125207   459.758877
# min     23.000000    5.000000     0.000000
# 25%     41.750000   11.000000    68.750000
# 50%     56.000000   14.000000   459.500000
# 75%     70.000000   16.000000   863.000000
# ...

# %% [markdown]
# ### Target: Limit, Predictors: Income

# %%
import matplotlib.pyplot as plt

df.plot(kind="scatter", x="Income", y="Limit")

# %%
import seaborn as sns

sns.lmplot(x='Income', y='Limit', data=df)

# %%
r = sns.residplot('Income','Limit', data=df)

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(df[['Income']], df['Limit'])
lin_reg.coef_, lin_reg.intercept_
# Out:
# (array([51.8750206]), 2389.8694089155265)

# %%
# Conclusion: The points in a residual plot are randomly dispersed around the horizontal axis, 
# so this linear regression model is appropriate for the data. The predictor Income is suitable for SLR.
# Scope is 51.88, intercept is 2389.87.

# %% [markdown]
# ### Target: Limit, Predictors: Rating

# %%
df.plot(kind="scatter", x="Rating", y="Limit")

# %%
sns.lmplot(x='Rating', y='Limit', data=df)

# %%
r = sns.residplot('Rating', 'Limit', data=df)

# %%
lin_reg.fit(df[['Rating']], df['Limit'])
lin_reg.coef_, lin_reg.intercept_
# Out:
# (array([14.87160712]), -542.928229986901)

# %%
# Conclusion: The points in a residual plot are randomly dispersed around the horizontal axis, 
# so this linear regression model is appropriate for the data. The predictor Rating is suitable for SLR.
# Scope is 14.87, intercept is -542.93.

# %% [markdown]
# ### Target: Limit, Predictors: Cards

# %%
df.plot(kind="scatter", x="Cards", y="Limit")

# %%
sns.lmplot(x='Cards', y='Limit', data=df)

# %%
r = sns.residplot('Cards', 'Limit', data=df)

# %%
lin_reg.fit(df[['Cards']], df['Limit'])
lin_reg.coef_, lin_reg.intercept_
# Out:
# (array([17.22189457]), 4684.666246822009)

# %%
# Conclusion: The points in a residual plot are not randomly dispersed around the horizontal axis, 
# so the predictor Cards is not suitable for SLR.

# %% [markdown]
# ### Target: Limit, Predictors: Age

# %%
df.plot(kind="scatter", x="Age", y="Limit")

# %%
sns.lmplot(x='Age', y='Limit', data=df)

# %%
r = sns.residplot('Age', 'Limit', data=df)

# %%
lin_reg.fit(df[['Age']], df['Limit'])
lin_reg.coef_, lin_reg.intercept_
# Out:
# (array([13.49982568]), 3984.0984540274258)

# %%
# Conclusion: The points in a residual plot are not randomly dispersed around the horizontal axis, 
# so the predictor Age is not suitable for SLR.

# %% [markdown]
# ### Target: Limit, Predictors: Education

# %%
df.plot(kind="scatter", x="Education", y="Limit")

# %%
sns.lmplot(x='Education', y='Limit', data=df)

# %%
sns.residplot('Education', 'Limit', data=df)

# %%
lin_reg.fit(df[['Education']], df['Limit'])
lin_reg.coef_, lin_reg.intercept_
# Out:
# (array([-17.39235309]), 4969.527149089043)

# %%
# Conclusion: The points in a residual plot are not randomly dispersed around the horizontal axis, 
# so the predictor Education is not suitable for SLR.
